# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
parcel = 1

# Prepare data
# Import dataset
df = pd.read_csv('data/parcel_{}_combined.csv'.format(parcel), delimiter=',')
df.head()

# Convert fecha column to datetime
df['date'] = pd.to_datetime(df['date'])

# Make date as index
df = df.set_index('date')

num_features = df.shape[1]

# interpolate missing values
df = df.interpolate(method='linear', axis=0)

# remove all nan values
df = df.dropna()

# Get the minimum and maximum values of 'eto'
min_et = df['eto'].min()
max_et = df['eto'].max()

# Normalize data
scaled_data = df[df.columns].values

scalers = {}
for column in df.columns:
    scalers[column] = MinMaxScaler(feature_range=(0, 1))
    scaled_data[:, df.columns.get_loc(column)] = scalers[column].fit_transform(scaled_data[:, df.columns.get_loc(column)].reshape(-1, 1)).flatten()

# Prepare input and output sequences
n_days = 7  # Number of days in each sequence
X = []
y = []
for i in range(n_days, len(df) - n_days + 1):
    X.append(scaled_data[i-n_days:i])
    y.append(scaled_data[i:i+n_days, df.columns.get_loc('eto')])  # Output sequence with 7 days of Evapotranspiration


X = np.array(X)
y = np.array(y)

# Define the callbacks
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', restore_best_weights=True)
# model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
lr_scheduler = LearningRateScheduler(lambda epoch: 0.001 * 0.9 ** epoch)  # Example learning rate scheduler


# Define LSTM model
model = keras.Sequential()
model.add(keras.layers.LSTM(32, activation='relu', input_shape=(n_days, X.shape[2])))
model.add(keras.layers.Dense(n_days))
model.compile(optimizer='adam', loss='mean_squared_error')

# Apply TimeSeriesSplit for cross-validation
mse_scores = []
mae_scores = []
tscv = TimeSeriesSplit(n_splits=5, test_size=1)  # Assuming you want to split the data into 5 folds
for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler])

    # Evaluate the model
    loss = model.evaluate(X_test, y_test)
    print(f"Fold {fold} - Test Loss: {loss}")

    # Make predictions
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    inv_predictions = scalers['eto'].inverse_transform(predictions).flatten()
    inv_actual = scalers['eto'].inverse_transform(y_test).flatten()
    inv_input = scalers['eto'].inverse_transform(X_test[:, :, df.columns.get_loc('eto')].reshape(1, -1)).flatten()

    # Calculate MSE
    mse = mean_squared_error(inv_actual, inv_predictions)
    mse_scores.append(mse)
    print(f"Fold {fold} - MSE: {mse}")

    # Calculate MAE
    mae = np.mean(np.abs(inv_actual - inv_predictions))
    mae_scores.append(mae)
    print(f"Fold {fold} - MAE: {mae}")

    # Plot predictions, actual values, and input data
    plt.figure(figsize=(12, 6))
    plt.plot(np.arange(len(inv_input)), inv_input, label='Input Data', linestyle='--')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_predictions, label='Predictions')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_actual, label='Actual')
    plt.xlabel('Time')
    plt.ylabel('Evapotranspiration')
    plt.title(f'Fold {fold} - Evapotranspiration Predictions vs Actual')
    plt.ylim(min_et, max_et)  # Set y-axis limits
    plt.legend()
    plt.show()

# Calculate average MSE across all splits
print(f"Average MSE: {np.mean(mse_scores)}")
print(f"Average MAE: {np.mean(mae_scores)}")
# Out:
# Epoch 1/100
# 10/10 [==============================] - 3s 49ms/step - loss: 0.3167 - val_loss: 0.5972 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2264 - val_loss: 0.3318 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1463 - val_loss: 0.1249 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0889 - val_loss: 0.0446 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0587 - val_loss: 0.0205 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0480 - val_loss: 0.0147 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0430 - val_loss: 0.0190 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0404 - val_loss: 0.0185 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0386 - val_loss: 0.0217 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0366 - val_loss: 0.0186 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0354 - val_loss: 0.0203 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0345 - val_loss: 0.0113 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0331 - val_loss: 0.0176 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0321 - val_loss: 0.0275 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0313 - val_loss: 0.0163 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0306 - val_loss: 0.0164 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0299 - val_loss: 0.0208 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0241 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0289 - val_loss: 0.0218 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0284 - val_loss: 0.0149 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0282 - val_loss: 0.0133 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0278 - val_loss: 0.0180 - lr: 1.0942e-04
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0113
# Fold 1 - Test Loss: 0.011271722614765167
# 1/1 [==============================] - 0s 261ms/step
# Fold 1 - MSE: 0.36658552026587315
# Fold 1 - MAE: 0.5539613968985508
# Epoch 1/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0324 - val_loss: 0.0199 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0292 - val_loss: 0.0092 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0266 - val_loss: 0.0219 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0240 - val_loss: 0.0115 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0217 - val_loss: 0.0196 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0199 - val_loss: 0.0105 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0184 - val_loss: 0.0062 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0164 - val_loss: 0.0096 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0150 - val_loss: 0.0051 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0050 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0126 - val_loss: 0.0042 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0031 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0109 - val_loss: 0.0027 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0023 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0099 - val_loss: 0.0026 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0023 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0020 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0090 - val_loss: 0.0017 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0020 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0019 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0019 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0019 - lr: 1.0942e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0018 - lr: 9.8477e-05
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0016 - lr: 8.8629e-05
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0081 - val_loss: 0.0016 - lr: 7.9766e-05
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0015 - lr: 7.1790e-05
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0015 - lr: 6.4611e-05
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0015 - lr: 5.8150e-05
# Epoch 29/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0015 - lr: 5.2335e-05
# Epoch 30/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0016 - lr: 4.7101e-05
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0016 - lr: 4.2391e-05
# Epoch 32/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0015 - lr: 3.8152e-05
# Epoch 33/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0015 - lr: 3.4337e-05
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0014 - lr: 3.0903e-05
# Epoch 35/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0014 - lr: 2.7813e-05
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0014 - lr: 2.5032e-05
# Epoch 37/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0015 - lr: 2.2528e-05
# Epoch 38/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0015 - lr: 2.0276e-05
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0015 - lr: 1.8248e-05
# Epoch 40/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0015 - lr: 1.6423e-05
# Epoch 41/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0014 - lr: 1.4781e-05
# Epoch 42/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0015 - lr: 1.3303e-05
# Epoch 43/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0014 - lr: 1.1973e-05
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0015 - lr: 1.0775e-05
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0014
# Fold 2 - Test Loss: 0.001440740772522986
# 1/1 [==============================] - 0s 27ms/step
# Fold 2 - MSE: 0.04685658553257773
# Fold 2 - MAE: 0.16830339081433504
# Epoch 1/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0011 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 9.9948e-04 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 8.4606e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 9.1773e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 9.3352e-04 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 8.7340e-04 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 4.2313e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 4.2319e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0010 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 2.9208e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 3.0806e-04 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0041 - val_loss: 0.0012 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 2.9297e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 2.9433e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 2.2708e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 3.2268e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 3.3225e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 2.4886e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 2.7095e-04 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 2.8197e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 2.5555e-04 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 2.5713e-04 - lr: 1.0942e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 2.4788e-04 - lr: 9.8477e-05
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 2.5951e-04 - lr: 8.8629e-05
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 2.4985e-04 - lr: 7.9766e-05
# 1/1 [==============================] - 0s 36ms/step - loss: 2.2708e-04
# Fold 3 - Test Loss: 0.00022707809694111347
# 1/1 [==============================] - 0s 29ms/step
# Fold 3 - MSE: 0.0073851549736397406
# Fold 3 - MAE: 0.07626459822362415
# Epoch 1/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0039 - val_loss: 6.5479e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 7.0617e-04 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 2.9446e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 2.1455e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0036 - val_loss: 2.2717e-04 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 2.2219e-04 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 2.2016e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 2.3012e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 1.3297e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 2.4121e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 3.0588e-04 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 1.3765e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 2.1189e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 1.7234e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 2.8447e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 1.4471e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 2.0380e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 1.9402e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 2.5223e-04 - lr: 1.5009e-04
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3297e-04
# Fold 4 - Test Loss: 0.00013296691759023815
# 1/1 [==============================] - 0s 30ms/step
# Fold 4 - MSE: 0.004324429556433398
# Fold 4 - MAE: 0.052218167441228376
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 4.3886e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 6.1315e-04 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 6.0634e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 3.8854e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 3.6072e-04 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0010 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 3.8208e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 5.7984e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 6.1475e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 8.4584e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0013 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 3.0539e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 8.6522e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 6.9672e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 5.3418e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 8.3979e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 5.7971e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 8.8980e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 8.9878e-04 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 6.1882e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0011 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 6.9224e-04 - lr: 1.0942e-04
# 1/1 [==============================] - 0s 31ms/step - loss: 3.0539e-04
# Fold 5 - Test Loss: 0.00030538998544216156
# 1/1 [==============================] - 0s 28ms/step
# Fold 5 - MSE: 0.00993208574757973
# Fold 5 - MAE: 0.0837861064988782
# Average MSE: 0.08701675521522076
# Average MAE: 0.18690673197532331

# %%
parcel = 2

# Prepare data
# Import dataset
df = pd.read_csv('data/parcel_{}_combined.csv'.format(parcel), delimiter=',')
df.head()

# Convert fecha column to datetime
df['date'] = pd.to_datetime(df['date'])

# Make date as index
df = df.set_index('date')

num_features = df.shape[1]

# interpolate missing values
df = df.interpolate(method='linear', axis=0)

# remove all nan values
df = df.dropna()

# Get the minimum and maximum values of 'eto'
min_et = df['eto'].min()
max_et = df['eto'].max()

# Normalize data
scaled_data = df[df.columns].values

scalers = {}
for column in df.columns:
    scalers[column] = MinMaxScaler(feature_range=(0, 1))
    scaled_data[:, df.columns.get_loc(column)] = scalers[column].fit_transform(scaled_data[:, df.columns.get_loc(column)].reshape(-1, 1)).flatten()

# Prepare input and output sequences
n_days = 7  # Number of days in each sequence
X = []
y = []
for i in range(n_days, len(df) - n_days + 1):
    X.append(scaled_data[i-n_days:i])
    y.append(scaled_data[i:i+n_days, df.columns.get_loc('eto')])  # Output sequence with 7 days of Evapotranspiration


X = np.array(X)
y = np.array(y)

# Define the callbacks
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', restore_best_weights=True)
# model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
lr_scheduler = LearningRateScheduler(lambda epoch: 0.001 * 0.9 ** epoch)  # Example learning rate scheduler


# Define LSTM model
model = keras.Sequential()
model.add(keras.layers.LSTM(32, activation='relu', input_shape=(n_days, X.shape[2])))
model.add(keras.layers.Dense(n_days))
model.compile(optimizer='adam', loss='mean_squared_error')

# Apply TimeSeriesSplit for cross-validation
mse_scores = []
mae_scores = []
tscv = TimeSeriesSplit(n_splits=5, test_size=1)  # Assuming you want to split the data into 5 folds
for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler])

    # Evaluate the model
    loss = model.evaluate(X_test, y_test)
    print(f"Fold {fold} - Test Loss: {loss}")

    # Make predictions
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    inv_predictions = scalers['eto'].inverse_transform(predictions).flatten()
    inv_actual = scalers['eto'].inverse_transform(y_test).flatten()
    inv_input = scalers['eto'].inverse_transform(X_test[:, :, df.columns.get_loc('eto')].reshape(1, -1)).flatten()

    # Calculate MSE
    mse = mean_squared_error(inv_actual, inv_predictions)
    mse_scores.append(mse)
    print(f"Fold {fold} - MSE: {mse}")

    # Calculate MAE
    mae = np.mean(np.abs(inv_actual - inv_predictions))
    mae_scores.append(mae)
    print(f"Fold {fold} - MAE: {mae}")

    # Plot predictions, actual values, and input data
    plt.figure(figsize=(12, 6))
    plt.plot(np.arange(len(inv_input)), inv_input, label='Input Data', linestyle='--')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_predictions, label='Predictions')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_actual, label='Actual')
    plt.xlabel('Time')
    plt.ylabel('Evapotranspiration')
    plt.title(f'Fold {fold} - Evapotranspiration Predictions vs Actual')
    plt.ylim(min_et, max_et)  # Set y-axis limits
    plt.legend()
    plt.show()

# Calculate average MSE across all splits
print(f"Average MSE: {np.mean(mse_scores)}")
print(f"Average MAE: {np.mean(mae_scores)}")
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3195 - val_loss: 0.2496 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2317 - val_loss: 0.1766 - lr: 9.0000e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1767 - val_loss: 0.1303 - lr: 8.1000e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1411 - val_loss: 0.1006 - lr: 7.2900e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1167 - val_loss: 0.0812 - lr: 6.5610e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0991 - val_loss: 0.0684 - lr: 5.9049e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0861 - val_loss: 0.0600 - lr: 5.3144e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0763 - val_loss: 0.0547 - lr: 4.7830e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0688 - val_loss: 0.0513 - lr: 4.3047e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0628 - val_loss: 0.0492 - lr: 3.8742e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0581 - val_loss: 0.0481 - lr: 3.4868e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0542 - val_loss: 0.0475 - lr: 3.1381e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 2.8243e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0486 - val_loss: 0.0473 - lr: 2.5419e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0465 - val_loss: 0.0474 - lr: 2.2877e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0448 - val_loss: 0.0477 - lr: 2.0589e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0433 - val_loss: 0.0479 - lr: 1.8530e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0421 - val_loss: 0.0481 - lr: 1.6677e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0411 - val_loss: 0.0482 - lr: 1.5009e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0403 - val_loss: 0.0483 - lr: 1.3509e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0395 - val_loss: 0.0484 - lr: 1.2158e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0389 - val_loss: 0.0485 - lr: 1.0942e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0383 - val_loss: 0.0485 - lr: 9.8477e-05
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0473
# Fold 1 - Test Loss: 0.047266919165849686
# 1/1 [==============================] - 0s 233ms/step
# Fold 1 - MSE: 0.05868816727896725
# Fold 1 - MAE: 0.21891904270405757
# Epoch 1/100
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0483 - val_loss: 0.0766 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0426 - val_loss: 0.0750 - lr: 9.0000e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0382 - val_loss: 0.0733 - lr: 8.1000e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0348 - val_loss: 0.0712 - lr: 7.2900e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0320 - val_loss: 0.0686 - lr: 6.5610e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0297 - val_loss: 0.0656 - lr: 5.9049e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0277 - val_loss: 0.0624 - lr: 5.3144e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0260 - val_loss: 0.0591 - lr: 4.7830e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0245 - val_loss: 0.0557 - lr: 4.3047e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0232 - val_loss: 0.0524 - lr: 3.8742e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0220 - val_loss: 0.0492 - lr: 3.4868e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0209 - val_loss: 0.0463 - lr: 3.1381e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0199 - val_loss: 0.0436 - lr: 2.8243e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0191 - val_loss: 0.0411 - lr: 2.5419e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0183 - val_loss: 0.0390 - lr: 2.2877e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0176 - val_loss: 0.0371 - lr: 2.0589e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0170 - val_loss: 0.0354 - lr: 1.8530e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0165 - val_loss: 0.0340 - lr: 1.6677e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0161 - val_loss: 0.0328 - lr: 1.5009e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0156 - val_loss: 0.0317 - lr: 1.3509e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0153 - val_loss: 0.0308 - lr: 1.2158e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0150 - val_loss: 0.0301 - lr: 1.0942e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0147 - val_loss: 0.0294 - lr: 9.8477e-05
# Epoch 24/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0144 - val_loss: 0.0288 - lr: 8.8629e-05
# Epoch 25/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0142 - val_loss: 0.0283 - lr: 7.9766e-05
# Epoch 26/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0140 - val_loss: 0.0279 - lr: 7.1790e-05
# Epoch 27/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0138 - val_loss: 0.0275 - lr: 6.4611e-05
# Epoch 28/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0136 - val_loss: 0.0272 - lr: 5.8150e-05
# Epoch 29/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0135 - val_loss: 0.0270 - lr: 5.2335e-05
# Epoch 30/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0133 - val_loss: 0.0267 - lr: 4.7101e-05
# Epoch 31/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0132 - val_loss: 0.0265 - lr: 4.2391e-05
# Epoch 32/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0131 - val_loss: 0.0263 - lr: 3.8152e-05
# Epoch 33/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0130 - val_loss: 0.0261 - lr: 3.4337e-05
# Epoch 34/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0129 - val_loss: 0.0259 - lr: 3.0903e-05
# Epoch 35/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0128 - val_loss: 0.0258 - lr: 2.7813e-05
# Epoch 36/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0127 - val_loss: 0.0256 - lr: 2.5032e-05
# Epoch 37/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0127 - val_loss: 0.0255 - lr: 2.2528e-05
# Epoch 38/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0126 - val_loss: 0.0254 - lr: 2.0276e-05
# Epoch 39/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0125 - val_loss: 0.0253 - lr: 1.8248e-05
# Epoch 40/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0125 - val_loss: 0.0252 - lr: 1.6423e-05
# Epoch 41/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0124 - val_loss: 0.0251 - lr: 1.4781e-05
# Epoch 42/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0124 - val_loss: 0.0250 - lr: 1.3303e-05
# Epoch 43/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0124 - val_loss: 0.0250 - lr: 1.1973e-05
# Epoch 44/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0123 - val_loss: 0.0249 - lr: 1.0775e-05
# Epoch 45/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0123 - val_loss: 0.0248 - lr: 9.6977e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0123 - val_loss: 0.0248 - lr: 8.7280e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0122 - val_loss: 0.0247 - lr: 7.8552e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0122 - val_loss: 0.0247 - lr: 7.0697e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0122 - val_loss: 0.0246 - lr: 6.3627e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0122 - val_loss: 0.0246 - lr: 5.7264e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0122 - val_loss: 0.0246 - lr: 5.1538e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0121 - val_loss: 0.0246 - lr: 4.6384e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0245 - lr: 4.1746e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0245 - lr: 3.7571e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0121 - val_loss: 0.0245 - lr: 3.3814e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 3.0433e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 2.7389e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 2.4650e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 2.2185e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 1.9967e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0244 - lr: 1.7970e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0243 - lr: 1.6173e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0121 - val_loss: 0.0243 - lr: 1.4556e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.3100e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.1790e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.0611e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 9.5500e-07
# Epoch 68/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 8.5950e-07
# Epoch 69/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 7.7355e-07
# Epoch 70/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 6.9620e-07
# Epoch 71/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 6.2658e-07
# Epoch 72/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 5.6392e-07
# Epoch 73/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 5.0753e-07
# Epoch 74/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 4.5678e-07
# Epoch 75/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 4.1110e-07
# Epoch 76/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 3.6999e-07
# Epoch 77/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 3.3299e-07
# Epoch 78/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 2.9969e-07
# Epoch 79/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 2.6972e-07
# Epoch 80/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 2.4275e-07
# Epoch 81/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 2.1847e-07
# Epoch 82/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.9663e-07
# Epoch 83/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.7696e-07
# Epoch 84/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.5927e-07
# Epoch 85/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.4334e-07
# Epoch 86/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.2901e-07
# Epoch 87/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.1611e-07
# Epoch 88/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0243 - lr: 1.0450e-07
# Epoch 89/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 9.4046e-08
# Epoch 90/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 8.4641e-08
# Epoch 91/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 7.6177e-08
# Epoch 92/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 6.8560e-08
# Epoch 93/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 6.1704e-08
# Epoch 94/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 5.5533e-08
# Epoch 95/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 4.9980e-08
# Epoch 96/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 4.4982e-08
# Epoch 97/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 4.0484e-08
# Epoch 98/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 3.6435e-08
# Epoch 99/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 3.2792e-08
# Epoch 100/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0120 - val_loss: 0.0242 - lr: 2.9513e-08
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0242
# Fold 2 - Test Loss: 0.024245504289865494
# 1/1 [==============================] - 0s 31ms/step
# Fold 2 - MSE: 0.030103954491173916
# Fold 2 - MAE: 0.14416885757446213
# Epoch 1/100
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0141 - val_loss: 0.0392 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0103 - val_loss: 0.0253 - lr: 9.0000e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0079 - val_loss: 0.0166 - lr: 8.1000e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0067 - val_loss: 0.0116 - lr: 7.2900e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0087 - lr: 6.5610e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0051 - val_loss: 0.0073 - lr: 5.9049e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0049 - val_loss: 0.0067 - lr: 5.3144e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0050 - val_loss: 0.0061 - lr: 4.7830e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0051 - val_loss: 0.0054 - lr: 4.3047e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0052 - val_loss: 0.0049 - lr: 3.8742e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0050 - val_loss: 0.0046 - lr: 3.4868e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0047 - val_loss: 0.0046 - lr: 3.1381e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0048 - lr: 2.8243e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0040 - val_loss: 0.0050 - lr: 2.5419e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0037 - val_loss: 0.0054 - lr: 2.2877e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0034 - val_loss: 0.0058 - lr: 2.0589e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0032 - val_loss: 0.0062 - lr: 1.8530e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0031 - val_loss: 0.0066 - lr: 1.6677e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0030 - val_loss: 0.0069 - lr: 1.5009e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0029 - val_loss: 0.0072 - lr: 1.3509e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0028 - val_loss: 0.0074 - lr: 1.2158e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0027 - val_loss: 0.0075 - lr: 1.0942e-04
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0046
# Fold 3 - Test Loss: 0.004580324981361628
# 1/1 [==============================] - 0s 36ms/step
# Fold 3 - MSE: 0.005687072104394056
# Fold 3 - MAE: 0.07039498488757039
# Epoch 1/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0044 - val_loss: 0.0061 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0035 - val_loss: 0.0067 - lr: 9.0000e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0031 - val_loss: 0.0078 - lr: 8.1000e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0031 - val_loss: 0.0086 - lr: 7.2900e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0032 - val_loss: 0.0089 - lr: 6.5610e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0032 - val_loss: 0.0087 - lr: 5.9049e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0032 - val_loss: 0.0084 - lr: 5.3144e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0031 - val_loss: 0.0080 - lr: 4.7830e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0030 - val_loss: 0.0077 - lr: 4.3047e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0029 - val_loss: 0.0073 - lr: 3.8742e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0028 - val_loss: 0.0070 - lr: 3.4868e-04
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0061
# Fold 4 - Test Loss: 0.006087861955165863
# 1/1 [==============================] - 0s 16ms/step
# Fold 4 - MSE: 0.007558879031232971
# Fold 4 - MAE: 0.058670244567245664
# Epoch 1/100
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0038 - val_loss: 0.0087 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0034 - val_loss: 0.0067 - lr: 9.0000e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0031 - val_loss: 0.0054 - lr: 8.1000e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0029 - val_loss: 0.0049 - lr: 7.2900e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0029 - val_loss: 0.0049 - lr: 6.5610e-04
# Epoch 6/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0028 - val_loss: 0.0053 - lr: 5.9049e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0026 - val_loss: 0.0058 - lr: 5.3144e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0024 - val_loss: 0.0065 - lr: 4.7830e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0023 - val_loss: 0.0071 - lr: 4.3047e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0023 - val_loss: 0.0074 - lr: 3.8742e-04
# Epoch 11/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0022 - val_loss: 0.0075 - lr: 3.4868e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0022 - val_loss: 0.0073 - lr: 3.1381e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0022 - val_loss: 0.0070 - lr: 2.8243e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0021 - val_loss: 0.0068 - lr: 2.5419e-04
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0049
# Fold 5 - Test Loss: 0.0049314978532493114
# 1/1 [==============================] - 0s 31ms/step
# Fold 5 - MSE: 0.006123104759464288
# Fold 5 - MAE: 0.06546707316807053
# Average MSE: 0.021632235533046495
# Average MAE: 0.11152404058028124
