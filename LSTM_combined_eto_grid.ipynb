# %%
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
parcel = 1

# Prepare data
# Import dataset
df = pd.read_csv('data/parcel_{}_combined.csv'.format(parcel), delimiter=',')
df.head()

# Convert fecha column to datetime
df['date'] = pd.to_datetime(df['date'])

# Make date as index
df = df.set_index('date')

num_features = df.shape[1]

# interpolate missing values
df = df.interpolate(method='linear', axis=0)

# remove all nan values
df = df.dropna()

# Get the minimum and maximum values of 'eto'
min_et = df['eto'].min()
max_et = df['eto'].max()

# Define the list of columns to consider for the grid search, excluding 'eto'
columns_to_search = [column for column in df.columns if column != 'eto']

# Define the range of column counts to consider (e.g., from 1 to the total number of columns - 1)
min_columns = 0
max_columns = len(columns_to_search)

# Define a variable to keep track of the best model and its performance
best_model = None
best_mse = float('inf')

# Perform grid search by iterating through different combinations of columns
for num_columns in range(min_columns, max_columns + 1):
    print("Number of columns: {}".format(num_columns))

    # Generate all possible combinations of columns for the current number of columns
    column_combinations = itertools.combinations(columns_to_search, num_columns)

    # Iterate through each combination of columns
    for columns in column_combinations:

        # Prepare data using the selected columns (including 'Evapotranspiration')
        selected_columns = list(columns) + ['eto']
        print("Selected columns: {}".format(selected_columns))

        # Normalize data
        scaled_data = df[selected_columns].values

        scalers = {}
        for column in df[selected_columns].columns:
            scalers[column] = MinMaxScaler(feature_range=(0, 1))
            scaled_data[:, df[selected_columns].columns.get_loc(column)] = scalers[column].fit_transform(scaled_data[:, df[selected_columns].columns.get_loc(column)].reshape(-1, 1)).flatten()

        # Prepare input and output sequences
        n_days = 7  # Number of days in each sequence
        X = []
        y = []
        for i in range(n_days, len(df[selected_columns]) - n_days + 1):
            X.append(scaled_data[i-n_days:i])
            y.append(scaled_data[i:i+n_days, df[selected_columns].columns.get_loc('eto')])  # Output sequence with 7 days of Evapotranspiration


        X = np.array(X)
        y = np.array(y)

        # Define the callbacks
        early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', restore_best_weights=True)
        # model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
        lr_scheduler = LearningRateScheduler(lambda epoch: 0.001 * 0.9 ** epoch)  # Example learning rate scheduler

        # Define LSTM model
        model = keras.Sequential()
        model.add(keras.layers.LSTM(64, activation='relu', input_shape=(n_days, X.shape[2])))
        model.add(keras.layers.Dense(n_days))
        model.compile(optimizer='adam', loss='mse')


        # Apply TimeSeriesSplit for cross-validation
        mse_scores = []
        mae_scores = []
        tscv = TimeSeriesSplit(n_splits=5, test_size=1)  # Assuming you want to split the data into 5 folds
        for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]

            # Train the model
            model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler], verbose=0)

            # Evaluate the model
            loss = model.evaluate(X_test, y_test, verbose=0)
            # print(f"Fold {fold} - Test Loss: {loss}")

            # Make predictions
            predictions = model.predict(X_test, verbose=0)

            # Inverse transform the predictions and actual values
            inv_predictions = scalers['eto'].inverse_transform(predictions).flatten()
            inv_actual = scalers['eto'].inverse_transform(y_test).flatten()
            inv_input = scalers['eto'].inverse_transform(X_test[:, :, df[selected_columns].columns.get_loc('eto')].reshape(1, -1)).flatten()

            # Calculate MSE
            mse = mean_squared_error(inv_actual, inv_predictions)
            mse_scores.append(mse)
            # print(f"Fold {fold} - MSE: {mse}")

            # Calculate MAE
            mae = np.mean(np.abs(inv_actual - inv_predictions))
            mae_scores.append(mae)
            # print(f"Fold {fold} - MAE: {mae}")

        # Calculate average MSE across all splits
        print(f"Average MSE: {np.mean(mse_scores)}")
        print(f"Average MAE: {np.mean(mae_scores)}")
        print()

        # Update the best model and MSE if the current model performs better
        if np.mean(mse_scores) < best_mse:
            best_columns = selected_columns
            best_model = model
            best_mse = np.mean(mse_scores)

# Print the best model and MSE
print(f"Best columns: {best_columns}")
print(f"Best MSE: {best_mse}")
# Out:
# Number of columns: 0
# Selected columns: ['eto']
# Average MSE: 0.02400600465487956
# Average MAE: 0.1298653967721182
#
# Number of columns: 1
# Selected columns: ['ndvi_mean', 'eto']
# Average MSE: 0.008353992059606385
# Average MAE: 0.07991512586632799
#
# Selected columns: ['ndwi_mean', 'eto']
# Average MSE: 0.027414676880432955
# Average MAE: 0.11491363922430944
#
# Selected columns: ['ndmi_mean', 'eto']
# Average MSE: 0.031051523605740122
# Average MAE: 0.1375115897509567
#
# Selected columns: ['gndvi_mean', 'eto']
# Average MSE: 0.021389863605581254
# Average MAE: 0.10915506658749155
#
# Selected columns: ['evi_mean', 'eto']
# Average MSE: 0.018250267330559254
# Average MAE: 0.10756652660759533
#
# Selected columns: ['evi2_mean', 'eto']
# Average MSE: 0.012858611499196445
# Average MAE: 0.09258231696304396
#
# Selected columns: ['savi_mean', 'eto']
# Average MSE: 0.016148142974371442
# Average MAE: 0.09453316458877595
#
# Selected columns: ['lst_mean', 'eto']
# Average MSE: 0.04001666084622698
# Average MAE: 0.1759957543976523
#
# Selected columns: ['sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.009096117951892507
# Average MAE: 0.06253416653068565
#
# Selected columns: ['sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.06007783694180165
# Average MAE: 0.14746337337883236
#
# Selected columns: ['sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.05036403603651639
# Average MAE: 0.11984707914080166
#
# Number of columns: 2
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'eto']
# Average MSE: 0.012337916398209803
# Average MAE: 0.07602178900582394
#
# Selected columns: ['ndvi_mean', 'ndmi_mean', 'eto']
# Average MSE: 0.009135188970060925
# Average MAE: 0.08041919739392625
#
# Selected columns: ['ndvi_mean', 'gndvi_mean', 'eto']
# Average MSE: 0.011253723052664208
# Average MAE: 0.08974672948097796
#
# Selected columns: ['ndvi_mean', 'evi_mean', 'eto']
# Average MSE: 0.01020154069695101
# Average MAE: 0.08229628940504373
#
# Selected columns: ['ndvi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.00736301950569278
# Average MAE: 0.07131839573140099
#
# Selected columns: ['ndvi_mean', 'savi_mean', 'eto']
# Average MSE: 0.014314417955628184
# Average MAE: 0.09451006589617558
#
# Selected columns: ['ndvi_mean', 'lst_mean', 'eto']
# Average MSE: 0.01376145497752325
# Average MAE: 0.09749212903392765
#
# Selected columns: ['ndvi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.019061839282606984
# Average MAE: 0.09077336190670944
#
# Selected columns: ['ndvi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.014986390606756512
# Average MAE: 0.08540997874980039
#
# Selected columns: ['ndvi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.0029498605333040896
# Average MAE: 0.044605601096640156
#
# Selected columns: ['ndwi_mean', 'ndmi_mean', 'eto']
# Average MSE: 0.02480179455168981
# Average MAE: 0.12686056487414704
#
# Selected columns: ['ndwi_mean', 'gndvi_mean', 'eto']
# Average MSE: 0.009286121512337573
# Average MAE: 0.08351561721490716
#
# Selected columns: ['ndwi_mean', 'evi_mean', 'eto']
# Average MSE: 0.026101894444426538
# Average MAE: 0.12369883743597983
#
# Selected columns: ['ndwi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.006937178854239642
# Average MAE: 0.07251128169468832
#
# Selected columns: ['ndwi_mean', 'savi_mean', 'eto']
# Average MSE: 0.012795269419891658
# Average MAE: 0.08265005197330762
#
# Selected columns: ['ndwi_mean', 'lst_mean', 'eto']
# Average MSE: 0.020092154283019362
# Average MAE: 0.11817894044214827
#
# Selected columns: ['ndwi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.059834263961829295
# Average MAE: 0.13999460461675295
#
# Selected columns: ['ndwi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.03823410479396325
# Average MAE: 0.12268601203451383
#
# Selected columns: ['ndwi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.023094347434164848
# Average MAE: 0.10187664942838788
#
# Selected columns: ['ndmi_mean', 'gndvi_mean', 'eto']
# Average MSE: 0.018599500571564176
# Average MAE: 0.09283213066568591
#
# Selected columns: ['ndmi_mean', 'evi_mean', 'eto']
# Average MSE: 0.02298248307431936
# Average MAE: 0.12107569659486397
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.01766733691615146
# Average MAE: 0.11222385787964377
#
# Selected columns: ['ndmi_mean', 'savi_mean', 'eto']
# Average MSE: 0.009282784342722204
# Average MAE: 0.08139784194012074
#
# Selected columns: ['ndmi_mean', 'lst_mean', 'eto']
# Average MSE: 0.022655486129160053
# Average MAE: 0.12838704214291252
#
# Selected columns: ['ndmi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.03258634811231219
# Average MAE: 0.12262195602728623
#
# Selected columns: ['ndmi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.011835640455351001
# Average MAE: 0.07250357577265401
#
# Selected columns: ['ndmi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.023090283335918456
# Average MAE: 0.1027105469995602
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'eto']
# Average MSE: 0.015366381201234958
# Average MAE: 0.098401697042041
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.012730334460422613
# Average MAE: 0.09680659500433794
#
# Selected columns: ['gndvi_mean', 'savi_mean', 'eto']
# Average MSE: 0.01509269927494893
# Average MAE: 0.09446704817791672
#
# Selected columns: ['gndvi_mean', 'lst_mean', 'eto']
# Average MSE: 0.02136105862880457
# Average MAE: 0.12327260060213611
#
# Selected columns: ['gndvi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.02014878916736215
# Average MAE: 0.09513750379912805
#
# Selected columns: ['gndvi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.016282071696733066
# Average MAE: 0.08854837853568037
#
# Selected columns: ['gndvi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.030005942582703383
# Average MAE: 0.10992367063249948
#
# Selected columns: ['evi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.010254740333231496
# Average MAE: 0.08064444841657373
#
# Selected columns: ['evi_mean', 'savi_mean', 'eto']
# Average MSE: 0.012641682226464076
# Average MAE: 0.09184275054931859
#
# Selected columns: ['evi_mean', 'lst_mean', 'eto']
# Average MSE: 0.0262757314609851
# Average MAE: 0.13883329243563114
#
# Selected columns: ['evi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.019343204454998226
# Average MAE: 0.08814581018564992
#
# Selected columns: ['evi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.04013525371940962
# Average MAE: 0.12818641327838715
#
# Selected columns: ['evi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.025912455299406452
# Average MAE: 0.09683373984512292
#
# Selected columns: ['evi2_mean', 'savi_mean', 'eto']
# Average MSE: 0.012201692307697196
# Average MAE: 0.0924910735305501
#
# Selected columns: ['evi2_mean', 'lst_mean', 'eto']
# Average MSE: 0.026008144626688212
# Average MAE: 0.13594727169738324
#
# Selected columns: ['evi2_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.023962328026038975
# Average MAE: 0.08935892159598449
#
# Selected columns: ['evi2_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.006913405166851155
# Average MAE: 0.06196289420614518
#
# Selected columns: ['evi2_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.008609822716815187
# Average MAE: 0.06515577627688286
#
# Selected columns: ['savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.041755645490344204
# Average MAE: 0.17947893500815434
#
# Selected columns: ['savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.006030972072582637
# Average MAE: 0.05600187301635826
#
# Selected columns: ['savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.017137733246462894
# Average MAE: 0.08659670140792097
#
# Selected columns: ['savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.00600065161295855
# Average MAE: 0.059446731567384704
#
# Selected columns: ['lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.010038812373819535
# Average MAE: 0.08041457211241203
#
# Selected columns: ['lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.01653196673156054
# Average MAE: 0.09008380741976027
#
# Selected columns: ['lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.0157247421217877
# Average MAE: 0.07575100272042491
#
# Selected columns: ['sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.0034057481098357435
# Average MAE: 0.047701512083714245
#
# Selected columns: ['sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0
#
# Selected columns: ['ndmi_mean', 'evi_mean', 'lst_mean', 'eto']
# Average MSE: 0.02215560651519314
# Average MAE: 0.12016668911369992
#
# Selected columns: ['ndmi_mean', 'evi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.014569713784343458
# Average MAE: 0.07889102920220548
#
# Selected columns: ['ndmi_mean', 'evi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.02058000405789006
# Average MAE: 0.08958439254760775
#
# Selected columns: ['ndmi_mean', 'evi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.013968125933514808
# Average MAE: 0.08847882212424431
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'savi_mean', 'eto']
# Average MSE: 0.01101332228447238
# Average MAE: 0.08799426401878145
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'lst_mean', 'eto']
# Average MSE: 0.03111955275730808
# Average MAE: 0.14675037454099632
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.006684073217380728
# Average MAE: 0.05598789892391305
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.005648359321670569
# Average MAE: 0.05716941459811561
#
# Selected columns: ['ndmi_mean', 'evi2_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.016291314341523356
# Average MAE: 0.08261210017301421
#
# Selected columns: ['ndmi_mean', 'savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.029406600045039456
# Average MAE: 0.14188360081887208
#
# Selected columns: ['ndmi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.01798935983934343
# Average MAE: 0.07695094213680591
#
# Selected columns: ['ndmi_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.02035459991228644
# Average MAE: 0.09566364607519265
#
# Selected columns: ['ndmi_mean', 'savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.029737375376863044
# Average MAE: 0.11077669338304155
#
# Selected columns: ['ndmi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.02900145156574733
# Average MAE: 0.1038928485792543
#
# Selected columns: ['ndmi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.016720738884221948
# Average MAE: 0.09069472612653696
#
# Selected columns: ['ndmi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.015560859106109748
# Average MAE: 0.09214201168137924
#
# Selected columns: ['ndmi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.006551444672659551
# Average MAE: 0.06473195305648957
#
# Selected columns: ['ndmi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.012603816767945836
# Average MAE: 0.07312138063080391
#
# Selected columns: ['ndmi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.041025605629228426
# Average MAE: 0.12008305646935465
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.019216034535360686
# Average MAE: 0.09838393744644094
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'savi_mean', 'eto']
# Average MSE: 0.011726667576560493
# Average MAE: 0.08796987720411852
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'lst_mean', 'eto']
# Average MSE: 0.019730169552704617
# Average MAE: 0.12048351124355428
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.02542773401820477
# Average MAE: 0.1080849164846002
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.009311367078293577
# Average MAE: 0.06664900666840334
#
# Selected columns: ['gndvi_mean', 'evi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.014978602542264602
# Average MAE: 0.07960333065110885
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'savi_mean', 'eto']
# Average MSE: 0.013319532717106161
# Average MAE: 0.08623795840205288
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'lst_mean', 'eto']
# Average MSE: 0.02754193425957719
# Average MAE: 0.14191363463110257
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.026393853627541996
# Average MAE: 0.0927353074210065
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.008902739338361646
# Average MAE: 0.06823237578722988
#
# Selected columns: ['gndvi_mean', 'evi2_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.023361008640611462
# Average MAE: 0.08823307496673988
#
# Selected columns: ['gndvi_mean', 'savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.02632774210025962
# Average MAE: 0.13386085510254203
#
# Selected columns: ['gndvi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.004332356565815757
# Average MAE: 0.050509210236217385
#
# Selected columns: ['gndvi_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.028891498327392972
# Average MAE: 0.11291105737491573
#
# Selected columns: ['gndvi_mean', 'savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.015277441515115097
# Average MAE: 0.08430093196946617
#
# Selected columns: ['gndvi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.026113831537697852
# Average MAE: 0.11834539864988076
#
# Selected columns: ['gndvi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.03901679669284143
# Average MAE: 0.11286549221739728
#
# Selected columns: ['gndvi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.018087098005898042
# Average MAE: 0.08418344661167561
#
# Selected columns: ['gndvi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.005855514824795693
# Average MAE: 0.05785718209402977
#
# Selected columns: ['gndvi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.021372344221103616
# Average MAE: 0.1049561604869624
#
# Selected columns: ['gndvi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.006261444007240588
# Average MAE: 0.05863751929146908
#
# Selected columns: ['evi_mean', 'evi2_mean', 'savi_mean', 'eto']
# Average MSE: 0.0070387883276503875
# Average MAE: 0.06448416238901719
#
# Selected columns: ['evi_mean', 'evi2_mean', 'lst_mean', 'eto']
# Average MSE: 0.026487320635554052
# Average MAE: 0.13553164727347894
#
# Selected columns: ['evi_mean', 'evi2_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.009022885869396365
# Average MAE: 0.06982804886175598
#
# Selected columns: ['evi_mean', 'evi2_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.02055555836238612
# Average MAE: 0.09822708161023351
#
# Selected columns: ['evi_mean', 'evi2_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.009429285867501734
# Average MAE: 0.06769752276673693
#
# Selected columns: ['evi_mean', 'savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.034188147671557256
# Average MAE: 0.16131609507970057
#
# Selected columns: ['evi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.006783562500503203
# Average MAE: 0.06848461003206455
#
# Selected columns: ['evi_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.01752455549473266
# Average MAE: 0.1007969485691645
#
# Selected columns: ['evi_mean', 'savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.008226581855402563
# Average MAE: 0.06716317647817333
#
# Selected columns: ['evi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.015710818788883175
# Average MAE: 0.08789418714873594
#
# Selected columns: ['evi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.02741972107816168
# Average MAE: 0.11939879094338077
#
# Selected columns: ['evi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.019822161739680325
# Average MAE: 0.10401270566667853
#
# Selected columns: ['evi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.028805677212126395
# Average MAE: 0.1199588176960839
#
# Selected columns: ['evi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.009093127174137265
# Average MAE: 0.07112982839467875
#
# Selected columns: ['evi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.011541472553311529
# Average MAE: 0.07294385100384485
#
# Selected columns: ['evi2_mean', 'savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.02323185514981223
# Average MAE: 0.12874621846724893
#
# Selected columns: ['evi2_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.03252583489105705
# Average MAE: 0.12050298519524175
#
# Selected columns: ['evi2_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.019541163526879866
# Average MAE: 0.08203713452085983
#
# Selected columns: ['evi2_mean', 'savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.02639933667531766
# Average MAE: 0.12928189063558776
#
# Selected columns: ['evi2_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.003842578341344846
# Average MAE: 0.05131902756983088
#
# Selected columns: ['evi2_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.008796911075843848
# Average MAE: 0.07291223471505326
#
# Selected columns: ['evi2_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.029267343794718854
# Average MAE: 0.1107085660039181
#
# Selected columns: ['evi2_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.007929154180379063
# Average MAE: 0.0637868763670619
#
# Selected columns: ['evi2_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.006342547837750871
# Average MAE: 0.06227584254984829
#
# Selected columns: ['evi2_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.02369556562668059
# Average MAE: 0.0829715994231558
#
# Selected columns: ['savi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.012060819313574625
# Average MAE: 0.07457963460805708
#
# Selected columns: ['savi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.004352857005758141
# Average MAE: 0.04669905362810149
#
# Selected columns: ['savi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.011408571265980015
# Average MAE: 0.07122958662071999
#
# Selected columns: ['savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.005850398432433907
# Average MAE: 0.060772285383578054
#
# Selected columns: ['savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.007392578789784122
# Average MAE: 0.07112936292375989
#
# Selected columns: ['savi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.011629833995877678
# Average MAE: 0.07057281206092228
#
# Selected columns: ['lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.011270008815705989
# Average MAE: 0.07234942152062238
#
# Selected columns: ['lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.007533056096002791
# Average MAE: 0.06088304254960164
#
# Selected columns: ['lst_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.013340854433969668
# Average MAE: 0.0825459557358113
#
# Selected columns: ['sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.01736483046572537
# Average MAE: 0.07689656284877212
#
# Number of columns: 4
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'gndvi_mean', 'eto']
# Average MSE: 0.011582118679345577
# Average MAE: 0.09124453719781829
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'evi_mean', 'eto']
# Average MSE: 0.008686157231394417
# Average MAE: 0.07394127180138657
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'evi2_mean', 'eto']
# Average MSE: 0.012472640301276585
# Average MAE: 0.09038224566712973
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'savi_mean', 'eto']
# Average MSE: 0.015687877535791858
# Average MAE: 0.10502807897451183
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'lst_mean', 'eto']
# Average MSE: 0.027200996900194053
# Average MAE: 0.1317588941613073
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.018993402412345574
# Average MAE: 0.09054307851986049
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.04623627483414807
# Average MAE: 0.1447818295225803
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'ndmi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.014727325884635887
# Average MAE: 0.08290610574216337
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'savi_mean', 'lst_mean', 'eto']
# Average MSE: 0.018257807322089693
# Average MAE: 0.10379396812283766
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.02914059169130633
# Average MAE: 0.118380693941702
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.027656605239228572
# Average MAE: 0.12095359506412513
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'savi_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.03404621406772555
# Average MAE: 0.12023142094514587
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.02634201929212703
# Average MAE: 0.1118107011756125
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.027456093472284487
# Average MAE: 0.1143139486507522
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.031848166723036746
# Average MAE: 0.12299896707340344
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.011154082558441091
# Average MAE: 0.07981186816157207
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.005053637699158465
# Average MAE: 0.06061113092851065
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'evi2_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.0053675401227570255
# Average MAE: 0.05803175509705889
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.007563666053126178
# Average MAE: 0.06922423896011384
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.014946034762870347
# Average MAE: 0.07813719846764637
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.02332170671563354
# Average MAE: 0.11546485332566925
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.00294828756832921
# Average MAE: 0.0428769558497852
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.029013424309581204
# Average MAE: 0.12880908600165056
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.026023849776046076
# Average MAE: 0.10062841080645957
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.024293897489989398
# Average MAE: 0.11199936785016758
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.02555792137805917
# Average MAE: 0.09830070526745852
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.018233869547714686
# Average MAE: 0.09870825693558709
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.005782483159664292
# Average MAE: 0.060421739227918894
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'eto']
# Average MSE: 0.015157594916147996
# Average MAE: 0.09904396197260766
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.016529338403199267
# Average MAE: 0.09534659000319021
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'lst_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.010151497627377963
# Average MAE: 0.07550963000861946
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.02804372350888138
# Average MAE: 0.10430844061715286
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.018412488458081577
# Average MAE: 0.10444895888348202
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'savi_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.02948305147022092
# Average MAE: 0.11418504403562046
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_humedad_90cm_mean', 'eto']
# Average MSE: 0.016471320377660876
# Average MAE: 0.09363876482905147
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'lst_mean', 'sensor_temperatura_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# Average MSE: 0.005468404746969188
# Average MAE: 0.061845014066114146
#
# Selected columns: ['ndvi_mean', 'ndwi_mean', 'gndvi_mean', 'evi2_mean', 'lst_mean', 'sensor_humedad_90cm_mean', 'sensor_salinidad_90cm_mean', 'eto']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Julio\atlas\project\atlas-ml\LSTM_combined_grid.ipynb Cell 2 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/Julio/atlas/project/atlas-ml/LSTM_combined_grid.ipynb#W1sZmlsZQ%3D%3D?line=88'>89</a> y_train, y_test = y[train_index], y[test_index]
#      <a href='vscode-notebook-cell:/c%3A/Users/Julio/atlas/project/atlas-ml/LSTM_combined_grid.ipynb#W1sZmlsZQ%3D%3D?line=90'>91</a> # Train the model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Julio/atlas/project/atlas-ml/LSTM_combined_grid.ipynb#W1sZmlsZQ%3D%3D?line=91'>92</a> model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler], verbose=0)
#      <a href='vscode-notebook-cell:/c%3A/Users/Julio/atlas/project/atlas-ml/LSTM_combined_grid.ipynb#W1sZmlsZQ%3D%3D?line=93'>94</a> # Evaluate the model
#      <a href='vscode-notebook-cell:/c%3A/Users/Julio/atlas/project/atlas-ml/LSTM_combined_grid.ipynb#W1sZmlsZQ%3D%3D?line=94'>95</a> loss = model.evaluate(X_test, y_test, verbose=0)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File c:\Users\Julio\atlas\project\atlas-ml\.venv\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
