# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
parcel = 1

# Prepare data
# Import dataset
df = pd.read_csv('data/parcel_{}_combined.csv'.format(parcel), delimiter=',')
df.head()

# Convert fecha column to datetime
df['date'] = pd.to_datetime(df['date'])

# Make date as index
df = df.set_index('date')

num_features = df.shape[1]

# interpolate missing values
df = df.interpolate(method='linear', axis=0)

# remove all nan values
df = df.dropna()

# Get the minimum and maximum values of 'eto'
min_et = df['eto'].min()
max_et = df['eto'].max()

# Normalize data
scaled_data = df[df.columns].values

scalers = {}
for column in df.columns:
    scalers[column] = MinMaxScaler(feature_range=(0, 1))
    scaled_data[:, df.columns.get_loc(column)] = scalers[column].fit_transform(scaled_data[:, df.columns.get_loc(column)].reshape(-1, 1)).flatten()

# Prepare input and output sequences
n_days = 7  # Number of days in each sequence
X = []
y = []
for i in range(n_days, len(df) - n_days + 1):
    X.append(scaled_data[i-n_days:i])
    y.append(scaled_data[i:i+n_days, df.columns.get_loc('eto')])  # Output sequence with 7 days of Evapotranspiration


X = np.array(X)
y = np.array(y)

# Define the callbacks
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', restore_best_weights=True)
# model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
lr_scheduler = LearningRateScheduler(lambda epoch: 0.001 * 0.9 ** epoch)  # Example learning rate scheduler


# Define LSTM model
model = keras.Sequential()
model.add(keras.layers.LSTM(32, activation='relu', input_shape=(n_days, X.shape[2])))
model.add(keras.layers.Dense(n_days))
model.compile(optimizer='adam', loss='mean_squared_error')

# Apply TimeSeriesSplit for cross-validation
mse_scores = []
mae_scores = []
tscv = TimeSeriesSplit(n_splits=5, test_size=1)  # Assuming you want to split the data into 5 folds
for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler])

    # Evaluate the model
    loss = model.evaluate(X_test, y_test)
    print(f"Fold {fold} - Test Loss: {loss}")

    # Make predictions
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    inv_predictions = scalers['eto'].inverse_transform(predictions).flatten()
    inv_actual = scalers['eto'].inverse_transform(y_test).flatten()
    inv_input = scalers['eto'].inverse_transform(X_test[:, :, df.columns.get_loc('eto')].reshape(1, -1)).flatten()

    # Calculate MSE
    mse = mean_squared_error(inv_actual, inv_predictions)
    mse_scores.append(mse)
    print(f"Fold {fold} - MSE: {mse}")

    # Calculate MAE
    mae = np.mean(np.abs(inv_actual - inv_predictions))
    mae_scores.append(mae)
    print(f"Fold {fold} - MAE: {mae}")

    # Plot predictions, actual values, and input data
    plt.figure(figsize=(12, 6))
    plt.plot(np.arange(len(inv_input)), inv_input, label='Input Data', linestyle='--')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_predictions, label='Predictions')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_actual, label='Actual')
    plt.xlabel('Time')
    plt.ylabel('Evapotranspiration')
    plt.title(f'Fold {fold} - Evapotranspiration Predictions vs Actual')
    plt.ylim(min_et, max_et)  # Set y-axis limits
    plt.legend()
    plt.show()

# Calculate average MSE across all splits
print(f"Average MSE: {np.mean(mse_scores)}")
print(f"Average MAE: {np.mean(mae_scores)}")
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 46ms/step - loss: 0.2339 - val_loss: 0.2728 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1333 - val_loss: 0.1483 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0831 - val_loss: 0.0721 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0520 - val_loss: 0.0507 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0368 - val_loss: 0.0268 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0291 - val_loss: 0.0225 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0255 - val_loss: 0.0244 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0214 - val_loss: 0.0065 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0191 - val_loss: 0.0085 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0170 - val_loss: 0.0072 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0044 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0139 - val_loss: 0.0036 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0128 - val_loss: 0.0026 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0023 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.0017 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0015 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0015 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0013 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0012 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 9.5979e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 9.2439e-04 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 9.6956e-04 - lr: 1.0942e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0011 - lr: 9.8477e-05
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 8.8899e-04 - lr: 8.8629e-05
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 8.9823e-04 - lr: 7.9766e-05
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 8.1289e-04 - lr: 7.1790e-05
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 7.7118e-04 - lr: 6.4611e-05
# Epoch 28/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 9.2467e-04 - lr: 5.8150e-05
# Epoch 29/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0011 - lr: 5.2335e-05
# Epoch 30/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0010 - lr: 4.7101e-05
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 8.3066e-04 - lr: 4.2391e-05
# Epoch 32/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 9.7409e-04 - lr: 3.8152e-05
# Epoch 33/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 8.3460e-04 - lr: 3.4337e-05
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 9.2042e-04 - lr: 3.0903e-05
# Epoch 35/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 9.9071e-04 - lr: 2.7813e-05
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 8.8986e-04 - lr: 2.5032e-05
# Epoch 37/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 8.6811e-04 - lr: 2.2528e-05
# 1/1 [==============================] - 0s 35ms/step - loss: 7.7118e-04
# Fold 1 - Test Loss: 0.0007711839280091226
# 1/1 [==============================] - 0s 273ms/step
# Fold 1 - MSE: 0.025080874638084588
# Fold 1 - MAE: 0.13477691066508019
# Epoch 1/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 6.5474e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0025 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0054 - val_loss: 0.0013 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 4.8565e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0012 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0034 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 6.8279e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0017 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 6.4827e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 3.2568e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0013 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 7.6834e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 4.8668e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 3.7733e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 3.7055e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 4.0873e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 3.2128e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 3.7171e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 4.0179e-04 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 4.1181e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 4.7545e-04 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 4.7245e-04 - lr: 1.0942e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 3.1563e-04 - lr: 9.8477e-05
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 4.6924e-04 - lr: 8.8629e-05
# Epoch 25/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 3.6967e-04 - lr: 7.9766e-05
# Epoch 26/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 3.4976e-04 - lr: 7.1790e-05
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 3.3366e-04 - lr: 6.4611e-05
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 3.2118e-04 - lr: 5.8150e-05
# Epoch 29/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 3.3279e-04 - lr: 5.2335e-05
# Epoch 30/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 3.6668e-04 - lr: 4.7101e-05
# Epoch 31/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 3.4156e-04 - lr: 4.2391e-05
# Epoch 32/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 3.3108e-04 - lr: 3.8152e-05
# Epoch 33/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 3.3373e-04 - lr: 3.4337e-05
# 1/1 [==============================] - 0s 37ms/step - loss: 3.1563e-04
# Fold 2 - Test Loss: 0.00031562961521558464
# 1/1 [==============================] - 0s 30ms/step
# Fold 2 - MSE: 0.010265082353628737
# Fold 2 - MAE: 0.08083464719811165
# Epoch 1/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0011 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0036 - val_loss: 0.0017 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0040 - val_loss: 0.0011 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 4.7131e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 6.2287e-04 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 7.4160e-04 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 3.6597e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 3.3732e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 2.9599e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 3.2080e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 3.8790e-04 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 2.2922e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 3.7862e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 5.6772e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 3.9503e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 3.4302e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 3.4397e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 2.9933e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 2.9289e-04 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 2.4994e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 4.2182e-04 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 2.9600e-04 - lr: 1.0942e-04
# 1/1 [==============================] - 0s 23ms/step - loss: 2.2922e-04
# Fold 3 - Test Loss: 0.00022921807249076664
# 1/1 [==============================] - 0s 30ms/step
# Fold 3 - MSE: 0.00745478158190577
# Fold 3 - MAE: 0.06908877158651691
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 9.7806e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 7.4962e-04 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 1.8884e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 4.1300e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 2.4648e-04 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 4.2417e-04 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 5.8420e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 9.2376e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 2.5432e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 3.3634e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 5.5586e-04 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 3.6655e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 2.6700e-04 - lr: 2.8243e-04
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8884e-04
# Fold 4 - Test Loss: 0.00018883946177084
# 1/1 [==============================] - 0s 28ms/step
# Fold 4 - MSE: 0.0061415538069819805
# Fold 4 - MAE: 0.06996462802497838
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 4.3160e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0011 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 6.8956e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 2.0865e-04 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0022 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 4.6711e-04 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 6.8862e-04 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 3.5805e-04 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 5.1302e-04 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 2.7801e-04 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 2.4667e-04 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 2.2741e-04 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.9440e-04 - lr: 2.8243e-04
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.1887e-04 - lr: 2.5419e-04
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.8086e-04 - lr: 2.2877e-04
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 1.6854e-04 - lr: 2.0589e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.6156e-04 - lr: 1.8530e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 2.0225e-04 - lr: 1.6677e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 1.8308e-04 - lr: 1.5009e-04
# Epoch 20/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 2.1190e-04 - lr: 1.3509e-04
# Epoch 21/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 1.5876e-04 - lr: 1.2158e-04
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 1.4814e-04 - lr: 1.0942e-04
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 1.4851e-04 - lr: 9.8477e-05
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.7656e-04 - lr: 8.8629e-05
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1887e-04
# Fold 5 - Test Loss: 0.0001188726382679306
# 1/1 [==============================] - 0s 29ms/step
# Fold 5 - MSE: 0.0038660285741241576
# Fold 5 - MAE: 0.05863129090289527
# Average MSE: 0.010561664190945046
# Average MAE: 0.08265924967551648

# %%
parcel = 2

# Prepare data
# Import dataset
df = pd.read_csv('data/parcel_{}_combined.csv'.format(parcel), delimiter=',')
df.head()

# Convert fecha column to datetime
df['date'] = pd.to_datetime(df['date'])

# Make date as index
df = df.set_index('date')

num_features = df.shape[1]

# interpolate missing values
df = df.interpolate(method='linear', axis=0)

# remove all nan values
df = df.dropna()

# Get the minimum and maximum values of 'eto'
min_et = df['eto'].min()
max_et = df['eto'].max()

# Normalize data
scaled_data = df[df.columns].values

scalers = {}
for column in df.columns:
    scalers[column] = MinMaxScaler(feature_range=(0, 1))
    scaled_data[:, df.columns.get_loc(column)] = scalers[column].fit_transform(scaled_data[:, df.columns.get_loc(column)].reshape(-1, 1)).flatten()

# Prepare input and output sequences
n_days = 7  # Number of days in each sequence
X = []
y = []
for i in range(n_days, len(df) - n_days + 1):
    X.append(scaled_data[i-n_days:i])
    y.append(scaled_data[i:i+n_days, df.columns.get_loc('eto')])  # Output sequence with 7 days of Evapotranspiration


X = np.array(X)
y = np.array(y)

# Define the callbacks
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', restore_best_weights=True)
# model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
lr_scheduler = LearningRateScheduler(lambda epoch: 0.001 * 0.9 ** epoch)  # Example learning rate scheduler


# Define LSTM model
model = keras.Sequential()
model.add(keras.layers.LSTM(32, activation='relu', input_shape=(n_days, X.shape[2])))
model.add(keras.layers.Dense(n_days))
model.compile(optimizer='adam', loss='mean_squared_error')

# Apply TimeSeriesSplit for cross-validation
mse_scores = []
mae_scores = []
tscv = TimeSeriesSplit(n_splits=5, test_size=1)  # Assuming you want to split the data into 5 folds
for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, lr_scheduler])

    # Evaluate the model
    loss = model.evaluate(X_test, y_test)
    print(f"Fold {fold} - Test Loss: {loss}")

    # Make predictions
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    inv_predictions = scalers['eto'].inverse_transform(predictions).flatten()
    inv_actual = scalers['eto'].inverse_transform(y_test).flatten()
    inv_input = scalers['eto'].inverse_transform(X_test[:, :, df.columns.get_loc('eto')].reshape(1, -1)).flatten()

    # Calculate MSE
    mse = mean_squared_error(inv_actual, inv_predictions)
    mse_scores.append(mse)
    print(f"Fold {fold} - MSE: {mse}")

    # Calculate MAE
    mae = np.mean(np.abs(inv_actual - inv_predictions))
    mae_scores.append(mae)
    print(f"Fold {fold} - MAE: {mae}")

    # Plot predictions, actual values, and input data
    plt.figure(figsize=(12, 6))
    plt.plot(np.arange(len(inv_input)), inv_input, label='Input Data', linestyle='--')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_predictions, label='Predictions')
    plt.plot(np.arange(len(inv_input), len(inv_input) + len(inv_actual)), inv_actual, label='Actual')
    plt.xlabel('Time')
    plt.ylabel('Evapotranspiration')
    plt.title(f'Fold {fold} - Evapotranspiration Predictions vs Actual')
    plt.ylim(min_et, max_et)  # Set y-axis limits
    plt.legend()
    plt.show()

# Calculate average MSE across all splits
print(f"Average MSE: {np.mean(mse_scores)}")
print(f"Average MAE: {np.mean(mae_scores)}")
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 46ms/step - loss: 0.2807 - val_loss: 0.4455 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2011 - val_loss: 0.2671 - lr: 9.0000e-04
# Epoch 3/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1265 - val_loss: 0.1042 - lr: 8.1000e-04
# Epoch 4/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0673 - val_loss: 0.0546 - lr: 7.2900e-04
# Epoch 5/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0403 - val_loss: 0.0242 - lr: 6.5610e-04
# Epoch 6/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.0151 - lr: 5.9049e-04
# Epoch 7/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0258 - val_loss: 0.0160 - lr: 5.3144e-04
# Epoch 8/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0233 - val_loss: 0.0191 - lr: 4.7830e-04
# Epoch 9/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0216 - val_loss: 0.0152 - lr: 4.3047e-04
# Epoch 10/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - val_loss: 0.0133 - lr: 3.8742e-04
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0195 - val_loss: 0.0180 - lr: 3.4868e-04
# Epoch 12/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0186 - val_loss: 0.0150 - lr: 3.1381e-04
# Epoch 13/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0180 - val_loss: 0.0140 - lr: 2.8243e-04
# Epoch 14/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0175 - val_loss: 0.0139 - lr: 2.5419e-04
# Epoch 15/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0170 - val_loss: 0.0136 - lr: 2.2877e-04
# Epoch 16/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0166 - val_loss: 0.0144 - lr: 2.0589e-04
# Epoch 17/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - val_loss: 0.0125 - lr: 1.8530e-04
# Epoch 18/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0160 - val_loss: 0.0128 - lr: 1.6677e-04
# Epoch 19/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0157 - val_loss: 0.0120 - lr: 1.5009e-04
# Epoch 20/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0154 - val_loss: 0.0117 - lr: 1.3509e-04
# Epoch 21/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0152 - val_loss: 0.0116 - lr: 1.2158e-04
# Epoch 22/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0150 - val_loss: 0.0111 - lr: 1.0942e-04
# Epoch 23/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0149 - val_loss: 0.0099 - lr: 9.8477e-05
# Epoch 24/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0098 - lr: 8.8629e-05
# Epoch 25/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0146 - val_loss: 0.0107 - lr: 7.9766e-05
# Epoch 26/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0145 - val_loss: 0.0104 - lr: 7.1790e-05
# Epoch 27/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0144 - val_loss: 0.0097 - lr: 6.4611e-05
# Epoch 28/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0143 - val_loss: 0.0099 - lr: 5.8150e-05
# Epoch 29/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0142 - val_loss: 0.0093 - lr: 5.2335e-05
# Epoch 30/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0095 - lr: 4.7101e-05
# Epoch 31/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0087 - lr: 4.2391e-05
# Epoch 32/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0140 - val_loss: 0.0090 - lr: 3.8152e-05
# Epoch 33/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0139 - val_loss: 0.0088 - lr: 3.4337e-05
# Epoch 34/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0088 - lr: 3.0903e-05
# Epoch 35/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0139 - val_loss: 0.0087 - lr: 2.7813e-05
# Epoch 36/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0138 - val_loss: 0.0087 - lr: 2.5032e-05
# Epoch 37/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0138 - val_loss: 0.0086 - lr: 2.2528e-05
# Epoch 38/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0137 - val_loss: 0.0086 - lr: 2.0276e-05
# Epoch 39/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0137 - val_loss: 0.0085 - lr: 1.8248e-05
# Epoch 40/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0137 - val_loss: 0.0084 - lr: 1.6423e-05
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0137 - val_loss: 0.0082 - lr: 1.4781e-05
# Epoch 42/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0137 - val_loss: 0.0082 - lr: 1.3303e-05
# Epoch 43/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0081 - lr: 1.1973e-05
# Epoch 44/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0081 - lr: 1.0775e-05
# Epoch 45/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0080 - lr: 9.6977e-06
# Epoch 46/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0081 - lr: 8.7280e-06
# Epoch 47/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0081 - lr: 7.8552e-06
# Epoch 48/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0080 - lr: 7.0697e-06
# Epoch 49/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0080 - lr: 6.3627e-06
# Epoch 50/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 5.7264e-06
# Epoch 51/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0080 - lr: 5.1538e-06
# Epoch 52/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0080 - lr: 4.6384e-06
# Epoch 53/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0080 - lr: 4.1746e-06
# Epoch 54/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.7571e-06
# Epoch 55/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.3814e-06
# Epoch 56/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0080 - lr: 3.0433e-06
# Epoch 57/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0080 - lr: 2.7389e-06
# Epoch 58/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.4650e-06
# Epoch 59/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.2185e-06
# Epoch 60/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.9967e-06
# Epoch 61/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.7970e-06
# Epoch 62/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.6173e-06
# Epoch 63/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.4556e-06
# Epoch 64/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.3100e-06
# Epoch 65/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.1790e-06
# Epoch 66/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.0611e-06
# Epoch 67/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 9.5500e-07
# Epoch 68/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 8.5950e-07
# Epoch 69/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 7.7355e-07
# Epoch 70/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 6.9620e-07
# Epoch 71/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 6.2658e-07
# Epoch 72/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 5.6392e-07
# Epoch 73/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 5.0753e-07
# Epoch 74/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 4.5678e-07
# Epoch 75/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 4.1110e-07
# Epoch 76/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.6999e-07
# Epoch 77/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.3299e-07
# Epoch 78/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.9969e-07
# Epoch 79/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.6972e-07
# Epoch 80/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.4275e-07
# Epoch 81/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.1847e-07
# Epoch 82/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.9663e-07
# Epoch 83/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.7696e-07
# Epoch 84/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.5927e-07
# Epoch 85/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.4334e-07
# Epoch 86/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.2901e-07
# Epoch 87/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.1611e-07
# Epoch 88/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 1.0450e-07
# Epoch 89/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 9.4046e-08
# Epoch 90/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 8.4641e-08
# Epoch 91/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 7.6177e-08
# Epoch 92/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 6.8560e-08
# Epoch 93/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 6.1704e-08
# Epoch 94/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 5.5533e-08
# Epoch 95/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 4.9980e-08
# Epoch 96/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 4.4982e-08
# Epoch 97/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 4.0484e-08
# Epoch 98/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.6435e-08
# Epoch 99/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 3.2792e-08
# Epoch 100/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0079 - lr: 2.9513e-08
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0079
# Fold 1 - Test Loss: 0.007879545912146568
# 1/1 [==============================] - 0s 223ms/step
# Fold 1 - MSE: 0.22384909992166763
# Fold 1 - MAE: 0.4473160977266222
# Epoch 1/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0128 - val_loss: 0.0054 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0116 - val_loss: 9.7648e-04 - lr: 9.0000e-04
# Epoch 3/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 9.8766e-04 - lr: 8.1000e-04
# Epoch 4/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0014 - lr: 7.2900e-04
# Epoch 5/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0095 - val_loss: 0.0016 - lr: 6.5610e-04
# Epoch 6/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 9.1812e-04 - lr: 5.9049e-04
# Epoch 7/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0014 - lr: 5.3144e-04
# Epoch 8/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0019 - lr: 4.7830e-04
# Epoch 9/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0013 - lr: 4.3047e-04
# Epoch 10/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0019 - lr: 3.8742e-04
# Epoch 11/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0017 - lr: 3.4868e-04
# Epoch 12/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0079 - val_loss: 0.0016 - lr: 3.1381e-04
# Epoch 13/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0013 - lr: 2.8243e-04
# Epoch 14/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0016 - lr: 2.5419e-04
# Epoch 15/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0017 - lr: 2.2877e-04
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0015 - lr: 2.0589e-04
# 1/1 [==============================] - 0s 33ms/step - loss: 9.1812e-04
# Fold 2 - Test Loss: 0.000918115780223161
# 1/1 [==============================] - 0s 27ms/step
# Fold 2 - MSE: 0.026082633496503537
# Fold 2 - MAE: 0.1378392362010715
# Epoch 1/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0089 - val_loss: 0.0014 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0014 - lr: 9.0000e-04
# Epoch 3/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0016 - lr: 8.1000e-04
# Epoch 4/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0018 - lr: 7.2900e-04
# Epoch 5/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 9.3874e-04 - lr: 6.5610e-04
# Epoch 6/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0031 - lr: 5.9049e-04
# Epoch 7/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 7.3096e-04 - lr: 5.3144e-04
# Epoch 8/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0027 - lr: 4.7830e-04
# Epoch 9/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0010 - lr: 4.3047e-04
# Epoch 10/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0018 - lr: 3.8742e-04
# Epoch 11/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0019 - lr: 3.4868e-04
# Epoch 12/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0016 - lr: 3.1381e-04
# Epoch 13/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0019 - lr: 2.8243e-04
# Epoch 14/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0016 - lr: 2.5419e-04
# Epoch 15/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0023 - lr: 2.2877e-04
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0017 - lr: 2.0589e-04
# Epoch 17/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0017 - lr: 1.8530e-04
# 1/1 [==============================] - 0s 30ms/step - loss: 7.3096e-04
# Fold 3 - Test Loss: 0.0007309560896828771
# 1/1 [==============================] - 0s 32ms/step
# Fold 3 - MSE: 0.020765635927649923
# Fold 3 - MAE: 0.1157400168594077
# Epoch 1/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0069 - val_loss: 9.6412e-04 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0075 - val_loss: 0.0019 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 6.9785e-04 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0070 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0068 - val_loss: 0.0050 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0013 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0059 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0014 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0039 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 0.0014 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.0019 - lr: 3.4868e-04
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0017 - lr: 3.1381e-04
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0028 - lr: 2.8243e-04
# 1/1 [==============================] - 0s 39ms/step - loss: 6.9785e-04
# Fold 4 - Test Loss: 0.0006978515884838998
# 1/1 [==============================] - 0s 33ms/step
# Fold 4 - MSE: 0.019825171233659584
# Fold 4 - MAE: 0.12036138448910107
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0022 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0035 - lr: 9.0000e-04
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0131 - lr: 8.1000e-04
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0062 - lr: 7.2900e-04
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 0.0023 - lr: 6.5610e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0066 - lr: 5.9049e-04
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0038 - lr: 5.3144e-04
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0045 - lr: 4.7830e-04
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0037 - lr: 4.3047e-04
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0057 - lr: 3.8742e-04
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0036 - lr: 3.4868e-04
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0022
# Fold 5 - Test Loss: 0.0021814159117639065
# 1/1 [==============================] - 0s 33ms/step
# Fold 5 - MSE: 0.061971543262216836
# Fold 5 - MAE: 0.1996664763470095
# Average MSE: 0.0704988167683395
# Average MAE: 0.20418464232464242
